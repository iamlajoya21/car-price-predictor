# %%
cars_data_l_pages
# Out:
# [[],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [['Dodge Challenger կուպե, 3.6 լ, 2018 թ.',
#    '$22,500 ',
#    'Արաբկիր, 2018 թ., 27,000 մղոն, Բենզին',
#    'Երեքշաբթի, Ապրիլ 16, 2024 09:52'],
#   ['Nissan Versa, 1.8 լ, 2017 թ.',
#    '$8,500 ',
#    'Դավիթաշեն, 2017 թ., 47,000 մղոն, Բենզին',
#    'Երեքշաբթի, Ապրիլ 16, 2024 09:52'],
#   ['Jeep Renegade, 2.4 լ, լիաքարշ, 2017 թ.',
#    '$15,500 ',
#    'Դավիթաշեն, 2017 թ., 107,000 մղոն, Բենզին',
#    'Երեքշաբթի, Ապրիլ 16, 2024 09:52'],
#   ['Mercedes-Benz E-Class, 2.0 լ, 2020 թ.',
#    '$45,000 ',
#    'Մալաթիա Սեբաստիա, 2020 թ., 7000 մղոն, Բենզին',
#    'Երեքշաբթի, Ապրիլ 16, 2024 09:52'],
#   ['Chevrolet Volt հետչբեք, 1.5 լ, հիբրիդ, 2018 թ.',
#    '$15,300 ',
#    'Ավան, 2018 թ., 44,267 կմ, Հիբրիդ',
#    'Երեքշաբթի, Ապրիլ 16, 2024 09:52'],
# ...
